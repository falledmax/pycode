# %% [markdown]
# # 正规方程法

# %% [markdown]
# ![image.png](attachment:56f5f118-34db-429e-b3b9-ae3c813c8d4a.png)

# %%
#导包
#from sklearn.datasets import load_boston #数据
from sklearn.preprocessing import StandardScaler        #数据标准化
from sklearn.model_selection import train_test_split    #数据划分 训练集 测试集
from sklearn.linear_model import LinearRegression       #选择正规方程的线性回归
from sklearn.linear_model import SGDRegressor           #梯度下降回归模型
from sklearn.metrics import mean_squared_error          #均方误差评估
from sklearn.linear_model import Ridge,RidgeCV

import pandas as pd
import numpy as np

#1. 加载数据
data_url = "http://lib.stat.cmu.edu/datasets/boston"
raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
target = raw_df.values[1::2, 2]

# %%
#2. 数据预处理
x_train,x_test,y_train,y_test=train_test_split(data,target,test_size=0.2,random_state=7)

# %%
#3. 特征工程 （特征提取，特征预处理）
#3.1 创建标准化对象
transfer=StandardScaler()
#3.2 进行标准化
x_train=transfer.fit_transform(x_train)
x_test=transfer.transform(x_test)

# %%
#4. 模型训练
#4.1 创建 线性回归 正规方程/梯度下降 模型对象 2选一，这两种方式都是寻找最佳w和b
estimator=LinearRegression(fit_intercept=True) #fit_intercept:是否需要截距 默认是需要
#estimator=SGDRegressor(fit_intercept=True,learning_rate='constant',eta0=0.01,)
                        #参1：是否算截距     参2：学习率是常量（可以改成变量） 参3：学习率初值
#4.2 模型训练
estimator.fit(x_train,y_train)
#4.3 打印模型计算的W和b
print(estimator.coef_) #特征有很多 会产生很多W
print(estimator.intercept_) #b只有一个
# Out:
# [-1.02255999  0.71236284  0.15252898  0.70916461 -1.75577224  3.72346696
#  -0.31277636 -2.71348259  2.25858954 -1.91158736 -1.99267986  0.88477592
#  -2.83238805]
# 22.522524752475295

# %%
#5. 模型预测
y_pre=estimator.predict(x_test)

# %%
#6. 模型评估
print(mean_squared_error(y_test,y_pre)) #均方误差 每个预测值与样本值的差值平方和/样本总数
