# %% [markdown]
# # 欠拟合

# %% [markdown]
# ![image.png](attachment:7461601c-8606-46ba-9dd3-ade9eb8efec6.png)

# %% [markdown]
# # 过拟合

# %% [markdown]
# ![image.png](attachment:e4b3d213-e229-48a9-82e9-d1c915507d76.png)

# %% [markdown]
# L1和L2正则化都是改善过拟合 在损失函数上面加一个惩罚项
# L1会把一些特征的W清零
# L2则相对平滑 他不会让W为0 但会特别小 这种方式同样也是用的最多的
# 正则化力度越大 w就会越小
