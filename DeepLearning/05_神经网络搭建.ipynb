# %% [markdown]
# # 题目

# %% [markdown]
# ![image.png](attachment:f06b0711-6946-4d7d-927f-4490bf2f2833.png)

# %%
# 导包
import torch
import torch.nn as nn
from torchsummary import summary #计算模型参数 查看模型结构

# %% [markdown]
# ![image.png](attachment:3f849d09-eee1-4e00-b275-0e0c6f94b302.png)

# %% [markdown]
# ![image.png](attachment:53a10d7b-1d87-4f79-a5b1-94cb1ed4c3ad.png)

# %% [markdown]
# ![image.png](attachment:097798ec-2cfa-445f-9b37-05478ec2a992.png)

# %% [markdown]
# ![image.png](attachment:20205606-7d37-4df2-857f-4d77483ff197.png)

# %% [markdown]
# ![image.png](attachment:26d14873-e052-492c-92fa-b8d8cf78c27f.png)

# %% [markdown]
# ![image.png](attachment:f192143b-be31-4e99-8020-a7e08e56d054.png)

# %% [markdown]
# 网络参数量统计方法：当前层参数数量=当前神经元个数*（上一层神经元个数+1）
